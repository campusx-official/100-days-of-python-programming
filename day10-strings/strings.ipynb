# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# - Editing Strings
# - Deleting Strings
# - Operations on Strings
# - String Functions

# %%
# Creating
c = 'Hello'
print(c)
# Out:
# Hello

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c = '''Hello'''
print(c)
# multi line strings
# Out:
# Hello

# %%
c = """Hello"""
print(c)
# Out:
# Hello

# %%
c = str("Hello")
c
# Out:
# 'Hello'

# %% [markdown]
# ### Accessing Substrings from a String

# %%
# Concept of Indexing
c = "hello"
print(c)
# Out:
# hello

# %%
print(c[0])
# Out:
# h

# %%
# Types of Indexing
# Postive Indexing
# Negative Indexing

print(c[-6])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-df8b850f3aba> in <module>
#       3 # Negative Indexing
#       4
# ----> 5 print(c[-6])
#
# IndexError: string index out of range

# %%
# Slicing
c = "Hello World"
print(c)
# Out:
# Hello World

# %%
print(c[0:5])
# Out:
# Hello

# %%
print(c[2:])
# Out:
# llo World

# %%
print(c[:4])
# Out:
# Hell

# %%
print(c[:])
# Out:
# Hello World

# %%
print(c)
# Out:
# Hello World

# %%
print(c[0:8:3])
# Out:
# HlW

# %%
print(c[0:6:-1])

# %%
print(c[-5:-1:2])
# Out:
# Wr

# %%
print(c[::-1])
# Out:
# dlroW olleH

# %%
print(c[-1:-5:-1])
# Out:
# dlro

# %%
"World" and "Hello"
# Out:
# 'Hello'

# %% [markdown]
# ### Editing and Deleting in Strings

# %%
c = "Hello"
print(c)
# Out:
# Hello

# %%
c[0] = 'X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-907c01db80c3> in <module>
# ----> 1 c[0] = 'X'
#
# TypeError: 'str' object does not support item assignment

# %%
# Strings are a Immutable Data Type

# %%
c = "world"
print(c)
# Out:
# world

# %%
print(c)
# Out:
# world

# %%
c[5] = "X"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-a04cbff15ae7> in <module>
# ----> 1 c[5] = "X"
#
# TypeError: 'str' object does not support item assignment

# %%
# Deletion
c
# Out:
# 'world'

# %%
del c

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-1dd5973cae19> in <module>
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
c = "hello"

# %%
print(c)
# Out:
# hello

# %%
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-b6bb46c364a5> in <module>
# ----> 1 del c[0]
#
# TypeError: 'str' object doesn't support item deletion

# %%
del c[:3:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-a5246862cc45> in <module>
# ----> 1 del c[:3:2]
#
# TypeError: 'str' object does not support item deletion

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
not "Hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %% [markdown]
# ### Operations on Strings
#
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
"Hello" + "-" + "world"
# Out:
# 'Hello-world'

# %%
print("*"*50)
# Out:
# **************************************************

# %%
print("Hello"*4)
# Out:
# HelloHelloHelloHello

# %%
"Hello" == "World"
# Out:
# False

# %%
"Hello" != "WOrld"
# Out:
# True

# %%
"Mumbai" > "Pune"
# Lexiographically
# Out:
# False

# %%
"Goa" < "Kolkata"
# Out:
# True

# %%
"kol" < "Kol"
# Out:
# False

# %%
"hello" and "world"
# Out:
# 'world'

# %%
"" -> False
"wreghr" -> True

# %%
"" and "Hello"
# Out:
# ''

# %%
"" or "world"
# Out:
# 'world'

# %%
"hello" or "world"
# Out:
# 'hello'

# %%
"hello" and "world"
# Out:
# 'world'

# %%
print(not "hello")
# Out:
# False

# %%
not ""
# Out:
# True

# %%
c = "hello world"
for i in c[::-1]:
    print(i)
# Out:
# d
# l
# r
# o
# w
#
# o
# l
# l
# e
# h

# %%
c
# Out:
# 'hello world'

# %%
'h' in c
# Out:
# True

# %%
'H' in c
# Out:
# False

# %%
'world' not in c
# Out:
# False
