# %% [markdown]
# ## Operators
#
# Operators are used to perform operations on variables and values. Python has the following operators:
#
# - Arithmetic operators
# - Comparison operators
# - Logical operators
# - Bitwise operators
# - Assignment operators
# - Identity operators
# - Membership operators

# %%
x = 5
y = 2

print(x + y)
# Out:
# 7

# %%
print(x - y)
# Out:
# 3

# %%
print(x * y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 2.5

# %%
print(x%y)
# Out:
# 1

# %%
print(x ** y)
# Out:
# 25

# %%
print(x // 2)
# Out:
# 2

# %%
print(x > y)
# Out:
# True

# %%
print(x < y)
# Out:
# False

# %%
print(x >= y)
# Out:
# True

# %%
print(x <= y)
# Out:
# False

# %%
print(x == y)
# Out:
# False

# %%
print(x != y)
# Out:
# True

# %%
# Logical Operators
x =True
y = False

print(x or y)
# Out:
# True

# %%
print(x and y)
# Out:
# False

# %%
print(not y)
# Out:
# True

# %%
# Bitwise

x = 2
y = 3

# %%
print(x & y)
# Out:
# 2

# %%
print(x | y)
# Out:
# 3

# %%
print(x >> 2)
# Out:
# 0

# %%
print(y << 3)
# Out:
# 24

# %%
print(~x)
# Out:
# -3

# %%
# Assignment
a = 3
print(a)
# Out:
# 3

# %%
a += 3
# a = a + 3
print(a)
# Out:
# 6

# %%
a -= 3
a *= 3
a &= 3

# %%
a++
++a
# Out:
#   File "<ipython-input-29-eb1e8ffb1845>", line 1
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
a = a + 3
a += 3

# %%
a = 3
b = 3

print(a is b)
# Out:
# True

# %%
a = "Hello"
b = "Hello"

print(a is b)
# Out:
# True

# %%
a = [1,2,3]
b = [1,2,3]

print(a is b)
# Out:
# False

# %%
a = "Hello-world"
b = "Hello-world"

print(a is not b)
# Out:
# True

# %%
x = "Delhi"

print("D" not in x)
# Out:
# False

# %%
x = (1,2,3)
print(5 in x)
# Out:
# False
